# %% [markdown]
# #### 자동차 회사는 새로운 전략을 수립하기 위해 4개의 시장으로 세분화했습니다. <br /> 기존 고객 분류 자료를 바탕으로 신규 고객이 어떤 분류에 속할지 예측해주세요!<br>
# #### 예측할 값(y): "Segmentation" (1,2,3,4) <br /> 평가: Macro f1-score <br /> data: train.csv, test.csv

# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('./Dataset/train.csv')
test_df = pd.read_csv('./Dataset/test.csv')

# %%
train_df.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  462809    Male           No   22        No  Healthcare              1.0
# 1  466315  Female          Yes   67       Yes    Engineer              1.0
# 2  461735    Male          Yes   67       Yes      Lawyer              0.0
# 3  461319    Male          Yes   56        No      Artist              0.0
# 4  460156    Male           No   32       Yes  Healthcare              1.0
#
#   Spending_Score  Family_Size  Var_1  Segmentation
# 0            Low          4.0  Cat_4             4
# 1            Low          1.0  Cat_6             2
# 2           High          2.0  Cat_6             2
# 3        Average          2.0  Cat_6             3
# 4            Low          3.0  Cat_6             3

# %%
test_df.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  459000    Male          Yes   59        No   Executive             11.0
# 3  459003    Male          Yes   47       Yes      Doctor              0.0
# 4  459005    Male          Yes   61       Yes      Doctor              5.0
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          1.0  Cat_6
# 1        Average          4.0  Cat_6
# 2           High          2.0  Cat_6
# 3           High          5.0  Cat_4
# 4            Low          3.0  Cat_6

# %%
train_df.isnull().sum()
# Out:
# ID                 0
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# Var_1              0
# Segmentation       0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# ID                 0
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# Var_1              0
# dtype: int64

# %%
train_df['Segmentation'].value_counts()
# Out:
# Segmentation
# 4    1757
# 3    1720
# 1    1616
# 2    1572
# Name: count, dtype: int64

# %%
train_df.columns
# Out:
# Index(['ID', 'Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
#        'Work_Experience', 'Spending_Score', 'Family_Size', 'Var_1',
#        'Segmentation'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['ID', 'Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
#        'Work_Experience', 'Spending_Score', 'Family_Size', 'Var_1'],
#       dtype='object')

# %%
y_train = train_df.pop('Segmentation')
y_train
# Out:
# 0       4
# 1       2
# 2       2
# 3       3
# 4       3
#        ..
# 6660    2
# 6661    4
# 6662    4
# 6663    2
# 6664    2
# Name: Segmentation, Length: 6665, dtype: int64

# %%
# 범주형 데이터 변화

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
le = LabelEncoder()
onehot = OneHotEncoder()
cols = ['Gender','Ever_Married', 'Graduated', 'Profession','Spending_Score','Family_Size','Var_1']
#for col in cols:

X_train = pd.get_dummies(train_df, columns=cols)
X_test = pd.get_dummies(train_df, columns= cols)
# for col in cols:
#     train_df[col] = le.fit_transform(train_df[col])
#     test_df[col] = le.fit_transform(test_df[col])

# %%
X_train.head()
# Out:
#        ID  Age  Work_Experience  Gender_Female  Gender_Male  Ever_Married_No  \
# 0  462809   22              1.0          False         True             True
# 1  466315   67              1.0           True        False            False
# 2  461735   67              0.0          False         True            False
# 3  461319   56              0.0          False         True            False
# 4  460156   32              1.0          False         True             True
#
#    Ever_Married_Yes  Graduated_No  Graduated_Yes  Profession_Artist  ...  \
# 0             False          True          False              False  ...
# 1              True         False           True              False  ...
# 2              True         False           True              False  ...
# 3              True          True          False               True  ...
# 4             False         False           True              False  ...
#
#    Family_Size_7.0  Family_Size_8.0  Family_Size_9.0  Var_1_Cat_1  \
# 0            False            False            False        False
# 1            False            False            False        False
# 2            False            False            False        False
# 3            False            False            False        False
# 4            False            False            False        False
#
#    Var_1_Cat_2  Var_1_Cat_3  Var_1_Cat_4  Var_1_Cat_5  Var_1_Cat_6  \
# 0        False        False         True        False        False
# 1        False        False        False        False         True
# 2        False        False        False        False         True
# 3        False        False        False        False         True
# 4        False        False        False        False         True
#
#    Var_1_Cat_7
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#
# [5 rows x 37 columns]

# %%
X_train.pop('ID')
cust_id = X_test.pop('ID')

# %%
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((6665, 36), (6665,), (6665, 36))

# %%
X_test.head()
# Out:
#    Age  Work_Experience  Gender_Female  Gender_Male  Ever_Married_No  \
# 0   22              1.0          False         True             True
# 1   67              1.0           True        False            False
# 2   67              0.0          False         True            False
# 3   56              0.0          False         True            False
# 4   32              1.0          False         True             True
#
#    Ever_Married_Yes  Graduated_No  Graduated_Yes  Profession_Artist  \
# 0             False          True          False              False
# 1              True         False           True              False
# 2              True         False           True              False
# 3              True          True          False               True
# 4             False         False           True              False
#
#    Profession_Doctor  ...  Family_Size_7.0  Family_Size_8.0  Family_Size_9.0  \
# 0              False  ...            False            False            False
# 1              False  ...            False            False            False
# 2              False  ...            False            False            False
# 3              False  ...            False            False            False
# 4              False  ...            False            False            False
#
#    Var_1_Cat_1  Var_1_Cat_2  Var_1_Cat_3  Var_1_Cat_4  Var_1_Cat_5  \
# 0        False        False        False         True        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    Var_1_Cat_6  Var_1_Cat_7
# 0        False        False
# 1         True        False
# 2         True        False
# 3         True        False
# 4         True        False
#
# [5 rows x 36 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators= 100, random_state = 42, max_depth= 5)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
train_df.head()
# Out:
#    Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0       1             0   22          0           5              1.0
# 1       0             1   67          1           2              1.0
# 2       1             1   67          1           7              0.0
# 3       1             1   56          0           0              0.0
# 4       1             0   32          1           5              1.0
#
#    Spending_Score  Family_Size  Var_1
# 0               2            3      3
# 1               2            0      5
# 2               1            1      5
# 3               0            1      5
# 4               2            2      5

# %%
# 교차 검증
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rf, X_train, y_train, scoring='f1_macro', cv=5)
print(scores)
print(scores.mean())
# Out:
# [0.50686749 0.51170453 0.48942041 0.50970924 0.48487653]
# 0.500515641858817

# %%
y_pred
# Out:
# array([4, 1, 3, ..., 4, 4, 2])

# %%
submission = pd.DataFrame({'ID': cust_id, 'Segmentation': y_pred})
submission.to_csv('9_26_11:28_2.csv', index=False)
